# %% [markdown]
# # My Jupyter Notebook on IBM Watson Studio

# %% [markdown]
# **Amir Abdellaoui**
#
# 100% human

# %% [markdown]
# *I am interested in data science because it involves curiosity*

# %% [markdown]
# ## the following code tests if a number is even or odd

# %%
def test(n):
    if(n % 2 == 0):
        return "even"
    else:
        return "odd"


print(test(100))
# Out:
# even

# %% [markdown]
# - one
# - two
# - three
# |Markdown|less|pretty|
# |---|---|---|
# |still|render|nicely|
# |1|2|3|
#
# www.ibm.com
